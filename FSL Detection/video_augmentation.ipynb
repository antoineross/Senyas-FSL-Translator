# %% [markdown]
# This notebook will implement Data Augmentation techniques to increase the dataset.

# %% [markdown]
# ##### Horizontal Flip:
# This script will create a flipped_videos folder with the same subdirectory structure as the videos folder. It will then iterate over all of the .mp4 files in each subdirectory of the videos folder, flip them horizontally using ffmpeg, and save the flipped videos to the corresponding subdirectory in the flipped_videos folder.

# %%
import os
import shutil
import subprocess

# Create the 'flipped_videos' folder if it doesn't already exist
if not os.path.exists(os.path.join('videos', 'flipped_videos')):
    os.mkdir(os.path.join('videos', 'flipped_videos'))

# Iterate over the subdirectories in the signed_videos folder
for subdir in os.listdir(os.path.join('videos', 'signed_videos')):
    # Ignore .DS_Store files
    if subdir == '.DS_Store':
        continue
    # Create a corresponding subdirectory in the 'flipped_videos' folder
    if not os.path.exists(os.path.join('videos', 'flipped_videos', subdir)):
        os.mkdir(os.path.join('videos', 'flipped_videos', subdir))
    # Iterate over the mp4 files in the current subdirectory
    for file in os.listdir(os.path.join('videos', 'signed_videos', subdir)):
        # Ignore .DS_Store files
        if file == '.DS_Store':
            continue
        if file.endswith('.mp4'):
            input_path = os.path.join('videos', 'signed_videos', subdir, file)
            output_path = os.path.join('videos', 'flipped_videos', subdir, file)
            # Use ffmpeg to flip the video horizontally and save it to the output path
            subprocess.run(['ffmpeg', '-i', input_path, '-vf', 'hflip', '-c:a', 'copy', output_path])
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/accident/4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf56.40.101
#   Duration: 00:00:01.09, start: 0.000000, bitrate: 2610 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 2606 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 59.94 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x13084ea00] using SAR=1/1
# [libx264 @ 0x13084ea00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13084ea00] profile High, level 4.0
# [libx264 @ 0x13084ea00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/flipped_videos/accident/4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 29.97 fps, 30k tbn, 29.97 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# frame=   31 fps=0.0 q=-1.0 Lsize=     388kB time=00:00:01.06 bitrate=2978.1kbits/s speed=1.68x
# video:369kB audio:17kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.608775%
# [libx264 @ 0x13084ea00] frame I:1     Avg QP:19.17  size: 37040
# [libx264 @ 0x13084ea00] frame P:16    Avg QP:17.97  size: 14320
# [libx264 @ 0x13084ea00] frame B:14    Avg QP:18.75  size:  7947
# [libx264 @ 0x13084ea00] consecutive B-frames: 35.5%  6.5% 19.4% 38.7%
# [libx264 @ 0x13084ea00] mb I  I16..4: 64.3% 32.2%  3.4%
# [libx264 @ 0x13084ea00] mb P  I16..4:  6.6% 19.7%  0.1%  P16..4: 23.5%  3.3%  1.2%  0.0%  0.0%    skip:45.7%
# [libx264 @ 0x13084ea00] mb B  I16..4:  1.0%  1.7%  0.0%  B16..8: 22.4%  1.4%  0.1%  direct:14.8%  skip:58.5%  L0:50.8% L1:47.1% BI: 2.0%
# [libx264 @ 0x13084ea00] 8x8 transform intra:66.3% inter:86.9%
# [libx264 @ 0x13084ea00] coded y,uvDC,uvAC intra: 14.8% 57.9% 6.2% inter: 3.5% 20.6% 0.0%
# [libx264 @ 0x13084ea00] i16 v,h,dc,p: 65% 18%  7% 10%
# [libx264 @ 0x13084ea00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17%  9% 64%  1%  2%  3%  1%  2%  1%
# [libx264 @ 0x13084ea00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 32% 14% 16%  5%  9% 10%  5%  7%  4%
# [libx264 @ 0x13084ea00] i8c dc,h,v,p: 44% 24% 29%  2%
# [libx264 @ 0x13084ea00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x13084ea00] ref P L0: 69.4%  6.9% 16.0%  7.7%
# [libx264 @ 0x13084ea00] ref B L0: 87.7%  9.2%  3.1%
# [libx264 @ 0x13084ea00] ref B L1: 97.6%  2.4%
# [libx264 @ 0x13084ea00] kb/s:2918.98
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/accident/1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     creation_time   : 1970-01-01T00:00:00.000000Z
#     title           : spreadthesign
#     encoder         : Lavf52.111.0
#   Duration: 00:00:03.64, start: 0.000000, bitrate: 286 kb/s
#     Stream #0:0(eng): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p, 320x240, 283 kb/s, 29.97 fps, 29.97 tbr, 2997 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 1970-01-01T00:00:00.000000Z
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x158012400] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x158012400] profile High, level 1.3
# [libx264 @ 0x158012400] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=7 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/flipped_videos/accident/1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : spreadthesign
#     encoder         : Lavf58.29.100
#     Stream #0:0(eng): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 320x240, q=-1--1, 29.97 fps, 11988 tbn, 29.97 tbc (default)
#     Metadata:
#       creation_time   : 1970-01-01T00:00:00.000000Z
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  109 fps=0.0 q=-1.0 Lsize=      68kB time=00:00:03.53 bitrate= 157.4kbits/s speed=32.6x
# video:66kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.938348%
# [libx264 @ 0x158012400] frame I:1     Avg QP:19.49  size:  6008
# [libx264 @ 0x158012400] frame P:52    Avg QP:20.73  size:   904
# [libx264 @ 0x158012400] frame B:56    Avg QP:26.67  size:   248
# [libx264 @ 0x158012400] consecutive B-frames: 26.6% 11.0% 11.0% 51.4%
# [libx264 @ 0x158012400] mb I  I16..4:  9.0% 66.0% 25.0%
# [libx264 @ 0x158012400] mb P  I16..4:  0.5%  1.6%  0.7%  P16..4: 45.3% 10.6%  6.6%  0.0%  0.0%    skip:34.7%
# [libx264 @ 0x158012400] mb B  I16..4:  0.1%  0.4%  0.2%  B16..8: 28.2%  2.6%  0.4%  direct: 0.4%  skip:67.7%  L0:41.3% L1:54.9% BI: 3.8%
# [libx264 @ 0x158012400] 8x8 transform intra:60.1% inter:71.9%
# [libx264 @ 0x158012400] coded y,uvDC,uvAC intra: 68.6% 69.2% 35.7% inter: 6.9% 22.3% 0.4%
# [libx264 @ 0x158012400] i16 v,h,dc,p: 39% 24% 15% 22%
# [libx264 @ 0x158012400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 15% 23%  7%  8%  6%  7% 10% 10%
# [libx264 @ 0x158012400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 15% 20%  9%  8%  7%  7%  7%  6%
# [libx264 @ 0x158012400] i8c dc,h,v,p: 49% 19% 24%  8%
# [libx264 @ 0x158012400] Weighted P-Frames: Y:5.8% UV:1.9%
# [libx264 @ 0x158012400] ref P L0: 65.2%  6.1% 22.0%  6.7%  0.1%
# [libx264 @ 0x158012400] ref B L0: 91.2%  7.4%  1.3%
# [libx264 @ 0x158012400] ref B L1: 95.5%  4.5%
# [libx264 @ 0x158012400] kb/s:147.19
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/accident/0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     creation_time   : 1970-01-01T00:00:00.000000Z
#     title           : spreadthesign
#     encoder         : Lavf52.111.0
#   Duration: 00:00:04.16, start: 0.000000, bitrate: 300 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p, 320x240, 297 kb/s, 25 fps, 25 tbr, 25 tbn, 50 tbc (default)
#     Metadata:
#       creation_time   : 1970-01-01T00:00:00.000000Z
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x15380e400] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x15380e400] profile High, level 1.3
# [libx264 @ 0x15380e400] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=7 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/flipped_videos/accident/0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : spreadthesign
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 320x240, q=-1--1, 25 fps, 12800 tbn, 25 tbc (default)
#     Metadata:
#       creation_time   : 1970-01-01T00:00:00.000000Z
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  104 fps=0.0 q=-1.0 Lsize=      73kB time=00:00:04.04 bitrate= 149.0kbits/s speed=28.5x
# video:72kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.786200%
# [libx264 @ 0x15380e400] frame I:1     Avg QP:19.48  size:  5135
# [libx264 @ 0x15380e400] frame P:38    Avg QP:21.10  size:  1280
# [libx264 @ 0x15380e400] frame B:65    Avg QP:25.41  size:   289
# [libx264 @ 0x15380e400] consecutive B-frames:  7.7% 21.2% 17.3% 53.8%
# [libx264 @ 0x15380e400] mb I  I16..4:  7.7% 68.0% 24.3%
# [libx264 @ 0x15380e400] mb P  I16..4:  0.4%  2.2%  0.8%  P16..4: 51.7% 15.5%  8.3%  0.0%  0.0%    skip:21.1%
# [libx264 @ 0x15380e400] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 35.1%  3.4%  0.7%  direct: 0.9%  skip:59.7%  L0:40.0% L1:54.9% BI: 5.2%
# [libx264 @ 0x15380e400] 8x8 transform intra:65.5% inter:76.6%
# [libx264 @ 0x15380e400] coded y,uvDC,uvAC intra: 76.1% 88.0% 47.8% inter: 9.6% 27.3% 0.8%
# [libx264 @ 0x15380e400] i16 v,h,dc,p: 25% 18% 11% 46%
# [libx264 @ 0x15380e400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 14% 22%  5% 12% 12%  8%  7%  7%
# [libx264 @ 0x15380e400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 14% 17%  6%  8%  9%  8%  8%  5%
# [libx264 @ 0x15380e400] i8c dc,h,v,p: 46% 23% 24%  7%
# [libx264 @ 0x15380e400] Weighted P-Frames: Y:26.3% UV:2.6%
# [libx264 @ 0x15380e400] ref P L0: 67.4%  9.9% 17.3%  4.4%  1.0%
# [libx264 @ 0x15380e400] ref B L0: 93.5%  6.1%  0.4%
# [libx264 @ 0x15380e400] ref B L1: 97.3%  2.7%
# [libx264 @ 0x15380e400] kb/s:139.51
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/accident/2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf56.40.101
#   Duration: 00:00:01.49, start: 0.000000, bitrate: 2436 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 2409 kb/s, 23.98 fps, 23.98 tbr, 90k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x127052e00] using SAR=1/1
# [libx264 @ 0x127052e00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x127052e00] profile High, level 4.0
# [libx264 @ 0x127052e00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=23 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/flipped_videos/accident/2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 23.98 fps, 24k tbn, 23.98 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# frame=   34 fps= 24 q=-1.0 Lsize=     463kB time=00:00:01.46 bitrate=2592.6kbits/s speed=1.05x
# video:438kB audio:23kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.511806%
# [libx264 @ 0x127052e00] frame I:1     Avg QP:17.61  size: 40058
# [libx264 @ 0x127052e00] frame P:15    Avg QP:17.16  size: 15743
# [libx264 @ 0x127052e00] frame B:18    Avg QP:17.66  size:  9526
# [libx264 @ 0x127052e00] consecutive B-frames: 26.5%  5.9%  8.8% 58.8%
# [libx264 @ 0x127052e00] mb I  I16..4: 62.4% 33.0%  4.6%
# [libx264 @ 0x127052e00] mb P  I16..4:  8.3% 26.3%  0.1%  P16..4: 23.5%  3.7%  1.4%  0.0%  0.0%    skip:36.6%
# [libx264 @ 0x127052e00] mb B  I16..4:  1.2%  1.6%  0.0%  B16..8: 25.7%  2.1%  0.2%  direct:20.5%  skip:48.7%  L0:35.4% L1:62.6% BI: 2.0%
# [libx264 @ 0x127052e00] 8x8 transform intra:67.9% inter:86.7%
# [libx264 @ 0x127052e00] coded y,uvDC,uvAC intra: 13.3% 50.7% 2.9% inter: 4.5% 27.3% 0.0%
# [libx264 @ 0x127052e00] i16 v,h,dc,p: 70% 16%  6%  8%
# [libx264 @ 0x127052e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21%  8% 62%  1%  2%  3%  1%  1%  1%
# [libx264 @ 0x127052e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 15% 14%  5% 10%  9%  6%  6%  4%
# [libx264 @ 0x127052e00] i8c dc,h,v,p: 48% 24% 26%  2%
# [libx264 @ 0x127052e00] Weighted P-Frames: Y:20.0% UV:0.0%
# [libx264 @ 0x127052e00] ref P L0: 59.8% 13.0% 19.0%  7.3%  0.8%
# [libx264 @ 0x127052e00] ref B L0: 90.0%  8.1%  1.8%
# [libx264 @ 0x127052e00] ref B L1: 97.7%  2.3%
# [libx264 @ 0x127052e00] kb/s:2525.43
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/accident/3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf56.40.101
#   Duration: 00:00:01.91, start: 0.000000, bitrate: 2393 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 2342 kb/s, 23.98 fps, 23.98 tbr, 90k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x140013000] using SAR=1/1
# [libx264 @ 0x140013000] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x140013000] profile High, level 4.0
# [libx264 @ 0x140013000] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=23 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/flipped_videos/accident/3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 23.98 fps, 24k tbn, 23.98 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# frame=   44 fps= 24 q=-1.0 Lsize=     597kB time=00:00:01.88 bitrate=2602.3kbits/s speed=1.04x
# video:566kB audio:29kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.452837%
# [libx264 @ 0x140013000] frame I:1     Avg QP:17.63  size: 40588
# [libx264 @ 0x140013000] frame P:14    Avg QP:16.50  size: 18455
# [libx264 @ 0x140013000] frame B:29    Avg QP:17.49  size:  9639
# [libx264 @ 0x140013000] consecutive B-frames:  4.5% 13.6% 27.3% 54.5%
# [libx264 @ 0x140013000] mb I  I16..4: 68.0% 28.4%  3.6%
# [libx264 @ 0x140013000] mb P  I16..4:  7.9% 29.6%  0.4%  P16..4: 25.7%  3.1%  1.2%  0.0%  0.0%    skip:32.1%
# [libx264 @ 0x140013000] mb B  I16..4:  1.2%  2.4%  0.0%  B16..8: 18.2%  1.6%  0.1%  direct:23.0%  skip:53.5%  L0:50.1% L1:47.4% BI: 2.5%
# [libx264 @ 0x140013000] 8x8 transform intra:69.8% inter:90.1%
# [libx264 @ 0x140013000] coded y,uvDC,uvAC intra: 20.0% 56.5% 6.3% inter: 3.9% 29.2% 0.0%
# [libx264 @ 0x140013000] i16 v,h,dc,p: 69% 14%  4% 13%
# [libx264 @ 0x140013000] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15%  8% 61%  2%  3%  3%  2%  4%  2%
# [libx264 @ 0x140013000] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 16% 18%  7%  9%  8%  8%  7%  4%
# [libx264 @ 0x140013000] i8c dc,h,v,p: 42% 26% 28%  4%
# [libx264 @ 0x140013000] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x140013000] ref P L0: 59.3%  7.8% 23.2%  9.8%
# [libx264 @ 0x140013000] ref B L0: 91.1%  6.9%  1.9%
# [libx264 @ 0x140013000] ref B L1: 97.5%  2.5%
# [libx264 @ 0x140013000] kb/s:2521.77
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/bed/4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf56.40.101
#   Duration: 00:00:01.19, start: 0.000000, bitrate: 2566 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 2552 kb/s, 23.98 fps, 23.98 tbr, 90k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x13780c000] using SAR=1/1
# [libx264 @ 0x13780c000] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13780c000] profile High, level 4.0
# [libx264 @ 0x13780c000] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=23 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/flipped_videos/bed/4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 23.98 fps, 24k tbn, 23.98 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# frame=   27 fps= 23 q=-1.0 Lsize=     406kB time=00:00:01.16 bitrate=2866.1kbits/s speed=0.97x
# video:386kB audio:18kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.519578%
# [libx264 @ 0x13780c000] frame I:1     Avg QP:18.52  size: 33654
# [libx264 @ 0x13780c000] frame P:17    Avg QP:17.70  size: 16055
# [libx264 @ 0x13780c000] frame B:9     Avg QP:18.26  size:  9772
# [libx264 @ 0x13780c000] consecutive B-frames: 44.4% 22.2% 33.3%  0.0%
# [libx264 @ 0x13780c000] mb I  I16..4: 66.1% 31.7%  2.3%
# [libx264 @ 0x13780c000] mb P  I16..4:  8.1% 24.8%  0.2%  P16..4: 19.8%  3.0%  0.9%  0.0%  0.0%    skip:43.2%
# [libx264 @ 0x13780c000] mb B  I16..4:  1.8%  3.2%  0.0%  B16..8: 20.7%  2.1%  0.2%  direct:15.3%  skip:56.8%  L0:52.4% L1:44.0% BI: 3.6%
# [libx264 @ 0x13780c000] 8x8 transform intra:68.0% inter:88.6%
# [libx264 @ 0x13780c000] coded y,uvDC,uvAC intra: 15.4% 60.9% 6.9% inter: 3.9% 21.8% 0.1%
# [libx264 @ 0x13780c000] i16 v,h,dc,p: 54% 19%  7% 20%
# [libx264 @ 0x13780c000] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 10% 59%  2%  2%  3%  1%  2%  1%
# [libx264 @ 0x13780c000] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 32% 15% 17%  5%  8%  8%  6%  6%  3%
# [libx264 @ 0x13780c000] i8c dc,h,v,p: 44% 23% 28%  5%
# [libx264 @ 0x13780c000] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x13780c000] ref P L0: 72.6%  6.4% 14.8%  6.2%
# [libx264 @ 0x13780c000] ref B L0: 86.6% 11.0%  2.4%
# [libx264 @ 0x13780c000] kb/s:2802.75
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/bed/1.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     creation_time   : 2017-03-16T03:31:41.000000Z
#     encoder         : HandBrake 1.0.3 2017022500
#   Duration: 00:00:02.97, start: 0.000000, bitrate: 1689 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1712 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 180k tbc (default)
#     Metadata:
#       creation_time   : 2017-03-16T03:31:41.000000Z
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 2 kb/s (default)
#     Metadata:
#       creation_time   : 2017-03-16T03:31:41.000000Z
#       handler_name    : Stereo
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x12a83ea00] using SAR=1/1
# [libx264 @ 0x12a83ea00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12a83ea00] profile High, level 3.1
# [libx264 @ 0x12a83ea00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/flipped_videos/bed/1.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 29.97 fps, 30k tbn, 29.97 tbc (default)
#     Metadata:
#       creation_time   : 2017-03-16T03:31:41.000000Z
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 2 kb/s (default)
#     Metadata:
#       creation_time   : 2017-03-16T03:31:41.000000Z
#       handler_name    : Stereo
# frame=   87 fps= 57 q=-1.0 Lsize=     377kB time=00:00:02.92 bitrate=1056.9kbits/s speed= 1.9x
# video:372kB audio:1kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.190354%
# [libx264 @ 0x12a83ea00] frame I:1     Avg QP:18.92  size: 28022
# [libx264 @ 0x12a83ea00] frame P:24    Avg QP:19.69  size:  9291
# [libx264 @ 0x12a83ea00] frame B:62    Avg QP:22.24  size:  2081
# [libx264 @ 0x12a83ea00] consecutive B-frames:  2.3%  4.6% 10.3% 82.8%
# [libx264 @ 0x12a83ea00] mb I  I16..4: 42.1% 46.7% 11.2%
# [libx264 @ 0x12a83ea00] mb P  I16..4:  6.9%  6.1%  0.4%  P16..4: 45.2%  6.9%  5.5%  0.0%  0.0%    skip:29.0%
# [libx264 @ 0x12a83ea00] mb B  I16..4:  0.5%  0.5%  0.0%  B16..8: 27.7%  0.8%  0.1%  direct: 2.6%  skip:67.8%  L0:43.4% L1:55.3% BI: 1.2%
# [libx264 @ 0x12a83ea00] 8x8 transform intra:46.3% inter:91.3%
# [libx264 @ 0x12a83ea00] coded y,uvDC,uvAC intra: 31.1% 71.3% 16.0% inter: 5.6% 20.2% 0.0%
# [libx264 @ 0x12a83ea00] i16 v,h,dc,p: 51% 18% 18% 13%
# [libx264 @ 0x12a83ea00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 36% 10% 41%  2%  2%  3%  2%  2%  2%
# [libx264 @ 0x12a83ea00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 46% 14% 17%  3%  4%  6%  3%  5%  2%
# [libx264 @ 0x12a83ea00] i8c dc,h,v,p: 48% 20% 30%  3%
# [libx264 @ 0x12a83ea00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12a83ea00] ref P L0: 63.8%  5.3% 21.6%  9.3%
# [libx264 @ 0x12a83ea00] ref B L0: 82.1% 13.3%  4.7%
# [libx264 @ 0x12a83ea00] ref B L1: 95.7%  4.3%
# [libx264 @ 0x12a83ea00] kb/s:1047.35
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/bed/0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : spreadthesign
#     encoder         : Lavf53.32.100
#   Duration: 00:00:02.76, start: 0.000000, bitrate: 380 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p, 320x240, 377 kb/s, 25 fps, 25 tbr, 25 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x13a00aa00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13a00aa00] profile High, level 1.3
# [libx264 @ 0x13a00aa00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=7 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/flipped_videos/bed/0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : spreadthesign
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 320x240, q=-1--1, 25 fps, 12800 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   69 fps=0.0 q=-1.0 Lsize=      45kB time=00:00:02.64 bitrate= 139.1kbits/s speed=  23x
# video:43kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.715002%
# [libx264 @ 0x13a00aa00] frame I:1     Avg QP:19.25  size:  5917
# [libx264 @ 0x13a00aa00] frame P:28    Avg QP:21.01  size:   982
# [libx264 @ 0x13a00aa00] frame B:40    Avg QP:25.80  size:   254
# [libx264 @ 0x13a00aa00] consecutive B-frames: 15.9% 20.3%  0.0% 63.8%
# [libx264 @ 0x13a00aa00] mb I  I16..4:  3.7% 78.3% 18.0%
# [libx264 @ 0x13a00aa00] mb P  I16..4:  0.4%  1.9%  0.7%  P16..4: 44.6% 11.3%  7.8%  0.0%  0.0%    skip:33.2%
# [libx264 @ 0x13a00aa00] mb B  I16..4:  0.0%  0.3%  0.1%  B16..8: 31.4%  2.6%  0.4%  direct: 0.5%  skip:64.6%  L0:43.0% L1:51.0% BI: 6.0%
# [libx264 @ 0x13a00aa00] 8x8 transform intra:70.6% inter:81.9%
# [libx264 @ 0x13a00aa00] coded y,uvDC,uvAC intra: 77.7% 84.3% 57.0% inter: 8.0% 22.0% 0.5%
# [libx264 @ 0x13a00aa00] i16 v,h,dc,p: 22% 25% 14% 39%
# [libx264 @ 0x13a00aa00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 14% 22%  5%  9% 11%  6%  6%  7%
# [libx264 @ 0x13a00aa00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 12% 21%  6%  5%  9%  5% 10%  4%
# [libx264 @ 0x13a00aa00] i8c dc,h,v,p: 51% 21% 22%  6%
# [libx264 @ 0x13a00aa00] Weighted P-Frames: Y:35.7% UV:0.0%
# [libx264 @ 0x13a00aa00] ref P L0: 69.9% 11.3% 14.3%  3.9%  0.6%
# [libx264 @ 0x13a00aa00] ref B L0: 93.4%  5.7%  0.9%
# [libx264 @ 0x13a00aa00] ref B L1: 97.7%  2.3%
# [libx264 @ 0x13a00aa00] kb/s:126.31
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/bed/2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf56.40.101
#   Duration: 00:00:01.07, start: 0.000000, bitrate: 2512 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 2532 kb/s, 23.98 fps, 23.98 tbr, 90k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x15300fa00] using SAR=1/1
# [libx264 @ 0x15300fa00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x15300fa00] profile High, level 4.0
# [libx264 @ 0x15300fa00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=23 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/flipped_videos/bed/2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 23.98 fps, 24k tbn, 23.98 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# frame=   24 fps=0.0 q=-1.0 Lsize=     359kB time=00:00:01.04 bitrate=2811.0kbits/s speed=1.15x
# video:340kB audio:16kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.580217%
# [libx264 @ 0x15300fa00] frame I:1     Avg QP:18.11  size: 37564
# [libx264 @ 0x15300fa00] frame P:13    Avg QP:17.63  size: 16420
# [libx264 @ 0x15300fa00] frame B:10    Avg QP:18.19  size:  9657
# [libx264 @ 0x15300fa00] consecutive B-frames: 33.3% 33.3%  0.0% 33.3%
# [libx264 @ 0x15300fa00] mb I  I16..4: 67.4% 29.8%  2.8%
# [libx264 @ 0x15300fa00] mb P  I16..4:  7.4% 25.9%  0.2%  P16..4: 24.4%  3.3%  1.2%  0.0%  0.0%    skip:37.6%
# [libx264 @ 0x15300fa00] mb B  I16..4:  1.4%  2.5%  0.0%  B16..8: 23.5%  1.8%  0.1%  direct:20.1%  skip:50.6%  L0:51.7% L1:46.3% BI: 2.0%
# [libx264 @ 0x15300fa00] 8x8 transform intra:68.1% inter:90.5%
# [libx264 @ 0x15300fa00] coded y,uvDC,uvAC intra: 13.4% 62.5% 5.6% inter: 3.9% 27.6% 0.1%
# [libx264 @ 0x15300fa00] i16 v,h,dc,p: 64% 17%  7% 12%
# [libx264 @ 0x15300fa00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20%  7% 63%  1%  2%  2%  1%  2%  1%
# [libx264 @ 0x15300fa00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 17% 17%  4%  9%  9%  6%  6%  3%
# [libx264 @ 0x15300fa00] i8c dc,h,v,p: 43% 24% 30%  3%
# [libx264 @ 0x15300fa00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x15300fa00] ref P L0: 70.1%  5.3% 16.8%  7.8%
# [libx264 @ 0x15300fa00] ref B L0: 89.5%  8.4%  2.1%
# [libx264 @ 0x15300fa00] ref B L1: 97.1%  2.9%
# [libx264 @ 0x15300fa00] kb/s:2777.97
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/bed/3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf56.40.101
#   Duration: 00:00:01.44, start: 0.000000, bitrate: 2524 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 2495 kb/s, 23.98 fps, 23.98 tbr, 90k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x12e009a00] using SAR=1/1
# [libx264 @ 0x12e009a00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12e009a00] profile High, level 4.0
# [libx264 @ 0x12e009a00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=23 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/flipped_videos/bed/3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 23.98 fps, 24k tbn, 23.98 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# frame=   33 fps= 24 q=-1.0 Lsize=     506kB time=00:00:01.41 bitrate=2924.2kbits/s speed=1.04x
# video:481kB audio:22kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.460640%
# [libx264 @ 0x12e009a00] frame I:1     Avg QP:17.93  size: 37306
# [libx264 @ 0x12e009a00] frame P:16    Avg QP:17.33  size: 17803
# [libx264 @ 0x12e009a00] frame B:16    Avg QP:18.11  size: 10621
# [libx264 @ 0x12e009a00] consecutive B-frames: 27.3% 12.1% 36.4% 24.2%
# [libx264 @ 0x12e009a00] mb I  I16..4: 65.6% 31.6%  2.8%
# [libx264 @ 0x12e009a00] mb P  I16..4:  8.8% 25.4%  0.2%  P16..4: 24.4%  3.7%  1.2%  0.0%  0.0%    skip:36.3%
# [libx264 @ 0x12e009a00] mb B  I16..4:  1.6%  2.8%  0.0%  B16..8: 22.8%  2.1%  0.1%  direct:21.0%  skip:49.6%  L0:53.8% L1:42.9% BI: 3.4%
# [libx264 @ 0x12e009a00] 8x8 transform intra:66.9% inter:89.6%
# [libx264 @ 0x12e009a00] coded y,uvDC,uvAC intra: 14.2% 63.5% 6.7% inter: 4.1% 29.6% 0.2%
# [libx264 @ 0x12e009a00] i16 v,h,dc,p: 60% 18%  8% 14%
# [libx264 @ 0x12e009a00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 10% 63%  1%  2%  2%  2%  1%  1%
# [libx264 @ 0x12e009a00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 18% 16%  5%  9%  9%  7%  5%  4%
# [libx264 @ 0x12e009a00] i8c dc,h,v,p: 39% 27% 29%  5%
# [libx264 @ 0x12e009a00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12e009a00] ref P L0: 68.2%  6.1% 17.5%  8.2%
# [libx264 @ 0x12e009a00] ref B L0: 89.3%  8.3%  2.4%
# [libx264 @ 0x12e009a00] ref B L1: 98.6%  1.4%
# [libx264 @ 0x12e009a00] kb/s:2860.23

# %% [markdown]
# ##### Zoom by 1.2x:
# This script will create a zoomed_videos folder with the same subdirectory structure as the videos folder. It will then iterate over all of the .mp4 files in each subdirectory of the videos folder, zoom them in by 1.2x using ffmpeg, and save the zoomed videos to the corresponding subdirectory in the zoomed_videos folder.

# %%
import os
import shutil
import subprocess

# Create the zoomed_videos folder if it doesn't already exist
if not os.path.exists(os.path.join('videos', 'zoomed_videos')):
    os.mkdir(os.path.join('videos', 'zoomed_videos'))

# Iterate over the subdirectories in the signed_videos folder
for subdir in os.listdir(os.path.join('videos', 'signed_videos')):
    # Ignore .DS_Store files
    if subdir == '.DS_Store':
        continue
    # Create a corresponding subdirectory in the zoomed_videos folder
    if not os.path.exists(os.path.join('videos', 'zoomed_videos', subdir)):
        os.mkdir(os.path.join('videos', 'zoomed_videos', subdir))
    # Iterate over the mp4 files in the current subdirectory
    for file in os.listdir(os.path.join('videos', 'signed_videos', subdir)):
        # Ignore .DS_Store files
        if file == '.DS_Store':
            continue
        if file.endswith('.mp4'):
            input_path = os.path.join('videos', 'signed_videos', subdir, file)
            output_path = os.path.join('videos', 'zoomed_videos', subdir, file)
            # Use ffmpeg to zoom in the video by 1.2x and save it to the output path
            subprocess.run(['ffmpeg', '-i', input_path, '-vf', 'scale=iw*1.5:ih*1.5', '-c:a', 'copy', output_path])
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/accident/1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     creation_time   : 1970-01-01T00:00:00.000000Z
#     title           : spreadthesign
#     encoder         : Lavf52.111.0
#   Duration: 00:00:03.64, start: 0.000000, bitrate: 286 kb/s
#     Stream #0:0(eng): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p, 320x240, 283 kb/s, 29.97 fps, 29.97 tbr, 2997 tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 1970-01-01T00:00:00.000000Z
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x14b80ec00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x14b80ec00] profile High, level 3.0
# [libx264 @ 0x14b80ec00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=11 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/zoomed_videos/accident/1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : spreadthesign
#     encoder         : Lavf58.29.100
#     Stream #0:0(eng): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 480x360, q=-1--1, 29.97 fps, 11988 tbn, 29.97 tbc (default)
#     Metadata:
#       creation_time   : 1970-01-01T00:00:00.000000Z
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  109 fps=0.0 q=-1.0 Lsize=     117kB time=00:00:03.53 bitrate= 272.1kbits/s speed=11.7x
# video:115kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.811058%
# [libx264 @ 0x14b80ec00] frame I:1     Avg QP:19.36  size:  9011
# [libx264 @ 0x14b80ec00] frame P:35    Avg QP:20.40  size:  2149
# [libx264 @ 0x14b80ec00] frame B:73    Avg QP:25.45  size:   456
# [libx264 @ 0x14b80ec00] consecutive B-frames:  6.4% 11.0%  5.5% 77.1%
# [libx264 @ 0x14b80ec00] mb I  I16..4: 10.1% 79.3% 10.6%
# [libx264 @ 0x14b80ec00] mb P  I16..4:  1.0%  3.8%  0.7%  P16..4: 45.5% 11.3%  6.4%  0.0%  0.0%    skip:31.1%
# [libx264 @ 0x14b80ec00] mb B  I16..4:  0.1%  0.5%  0.1%  B16..8: 26.3%  1.7%  0.2%  direct: 0.5%  skip:70.6%  L0:36.3% L1:60.1% BI: 3.6%
# [libx264 @ 0x14b80ec00] 8x8 transform intra:72.2% inter:82.8%
# [libx264 @ 0x14b80ec00] coded y,uvDC,uvAC intra: 59.6% 62.4% 21.2% inter: 6.5% 18.3% 0.2%
# [libx264 @ 0x14b80ec00] i16 v,h,dc,p: 42% 23%  9% 26%
# [libx264 @ 0x14b80ec00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 14% 21%  5%  8%  8%  8%  6%  8%
# [libx264 @ 0x14b80ec00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 14% 17%  6% 13%  9%  8%  5%  5%
# [libx264 @ 0x14b80ec00] i8c dc,h,v,p: 53% 17% 22%  8%
# [libx264 @ 0x14b80ec00] Weighted P-Frames: Y:5.7% UV:2.9%
# [libx264 @ 0x14b80ec00] ref P L0: 66.0%  7.1% 20.6%  6.2%  0.2%
# [libx264 @ 0x14b80ec00] ref B L0: 90.9%  7.8%  1.4%
# [libx264 @ 0x14b80ec00] ref B L1: 96.2%  3.8%
# [libx264 @ 0x14b80ec00] kb/s:258.43
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/accident/0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     creation_time   : 1970-01-01T00:00:00.000000Z
#     title           : spreadthesign
#     encoder         : Lavf52.111.0
#   Duration: 00:00:04.16, start: 0.000000, bitrate: 300 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p, 320x240, 297 kb/s, 25 fps, 25 tbr, 25 tbn, 50 tbc (default)
#     Metadata:
#       creation_time   : 1970-01-01T00:00:00.000000Z
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x131009a00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x131009a00] profile High, level 2.1
# [libx264 @ 0x131009a00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=11 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/zoomed_videos/accident/0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : spreadthesign
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 480x360, q=-1--1, 25 fps, 12800 tbn, 25 tbc (default)
#     Metadata:
#       creation_time   : 1970-01-01T00:00:00.000000Z
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  104 fps=0.0 q=-1.0 Lsize=     140kB time=00:00:04.04 bitrate= 284.6kbits/s speed=9.91x
# video:138kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.434559%
# [libx264 @ 0x131009a00] frame I:1     Avg QP:19.46  size:  7580
# [libx264 @ 0x131009a00] frame P:38    Avg QP:20.90  size:  2453
# [libx264 @ 0x131009a00] frame B:65    Avg QP:24.66  size:   619
# [libx264 @ 0x131009a00] consecutive B-frames: 12.5%  9.6%  8.7% 69.2%
# [libx264 @ 0x131009a00] mb I  I16..4:  7.8% 82.2% 10.0%
# [libx264 @ 0x131009a00] mb P  I16..4:  0.7%  3.9%  0.4%  P16..4: 52.4% 12.5%  6.9%  0.0%  0.0%    skip:23.3%
# [libx264 @ 0x131009a00] mb B  I16..4:  0.0%  0.3%  0.1%  B16..8: 34.4%  2.4%  0.4%  direct: 1.3%  skip:61.2%  L0:41.1% L1:54.6% BI: 4.2%
# [libx264 @ 0x131009a00] 8x8 transform intra:79.7% inter:85.9%
# [libx264 @ 0x131009a00] coded y,uvDC,uvAC intra: 65.6% 78.1% 33.7% inter: 10.1% 28.4% 0.4%
# [libx264 @ 0x131009a00] i16 v,h,dc,p: 23% 14% 10% 53%
# [libx264 @ 0x131009a00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 13% 21%  8%  6%  7%  5% 10%  7%
# [libx264 @ 0x131009a00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 13% 15%  5% 10% 10%  7%  6%  4%
# [libx264 @ 0x131009a00] i8c dc,h,v,p: 49% 21% 23%  7%
# [libx264 @ 0x131009a00] Weighted P-Frames: Y:13.2% UV:2.6%
# [libx264 @ 0x131009a00] ref P L0: 67.4%  8.6% 18.8%  4.8%  0.4%
# [libx264 @ 0x131009a00] ref B L0: 92.6%  6.7%  0.7%
# [libx264 @ 0x131009a00] ref B L1: 96.9%  3.1%
# [libx264 @ 0x131009a00] kb/s:271.23
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/accident/2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf56.40.101
#   Duration: 00:00:01.49, start: 0.000000, bitrate: 2436 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 2409 kb/s, 23.98 fps, 23.98 tbr, 90k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x12400c000] using SAR=1/1
# [libx264 @ 0x12400c000] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12400c000] profile High, level 5.0
# [libx264 @ 0x12400c000] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=23 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/zoomed_videos/accident/2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 2880x1620 [SAR 1:1 DAR 16:9], q=-1--1, 23.98 fps, 24k tbn, 23.98 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# frame=   34 fps= 10 q=-1.0 Lsize=     893kB time=00:00:01.46 bitrate=5003.6kbits/s speed=0.44x
# video:868kB audio:23kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.267288%
# [libx264 @ 0x12400c000] frame I:1     Avg QP:18.00  size: 65319
# [libx264 @ 0x12400c000] frame P:13    Avg QP:17.99  size: 32276
# [libx264 @ 0x12400c000] frame B:20    Avg QP:18.03  size: 20180
# [libx264 @ 0x12400c000] consecutive B-frames: 17.6%  5.9% 17.6% 58.8%
# [libx264 @ 0x12400c000] mb I  I16..4: 46.5% 51.6%  1.9%
# [libx264 @ 0x12400c000] mb P  I16..4:  9.5% 36.5%  0.1%  P16..4: 18.6%  3.5%  1.2%  0.0%  0.0%    skip:30.6%
# [libx264 @ 0x12400c000] mb B  I16..4:  2.0%  1.7%  0.0%  B16..8: 21.4%  2.6%  0.2%  direct:20.8%  skip:51.3%  L0:39.9% L1:58.4% BI: 1.7%
# [libx264 @ 0x12400c000] 8x8 transform intra:72.5% inter:91.8%
# [libx264 @ 0x12400c000] coded y,uvDC,uvAC intra: 10.0% 38.3% 7.3% inter: 4.4% 28.4% 0.0%
# [libx264 @ 0x12400c000] i16 v,h,dc,p: 65% 19%  4% 12%
# [libx264 @ 0x12400c000] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 10% 56%  1%  1%  1%  1%  2%  1%
# [libx264 @ 0x12400c000] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 32% 18% 16%  5%  8%  7%  6%  6%  3%
# [libx264 @ 0x12400c000] i8c dc,h,v,p: 63% 17% 18%  1%
# [libx264 @ 0x12400c000] Weighted P-Frames: Y:7.7% UV:0.0%
# [libx264 @ 0x12400c000] ref P L0: 62.0% 13.7% 17.7%  6.3%  0.3%
# [libx264 @ 0x12400c000] ref B L0: 87.6% 10.4%  2.0%
# [libx264 @ 0x12400c000] ref B L1: 97.2%  2.8%
# [libx264 @ 0x12400c000] kb/s:5012.37
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/accident/3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf56.40.101
#   Duration: 00:00:01.91, start: 0.000000, bitrate: 2393 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 2342 kb/s, 23.98 fps, 23.98 tbr, 90k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x12400d600] using SAR=1/1
# [libx264 @ 0x12400d600] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12400d600] profile High, level 5.0
# [libx264 @ 0x12400d600] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=23 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/zoomed_videos/accident/3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 2880x1620 [SAR 1:1 DAR 16:9], q=-1--1, 23.98 fps, 24k tbn, 23.98 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# frame=   44 fps= 11 q=-1.0 Lsize=    1143kB time=00:00:01.88 bitrate=4978.9kbits/s speed=0.475x
# video:1111kB audio:29kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.237634%
# [libx264 @ 0x12400d600] frame I:1     Avg QP:17.82  size: 65448
# [libx264 @ 0x12400d600] frame P:13    Avg QP:17.32  size: 34731
# [libx264 @ 0x12400d600] frame B:30    Avg QP:17.78  size: 20675
# [libx264 @ 0x12400d600] consecutive B-frames:  4.5%  9.1% 13.6% 72.7%
# [libx264 @ 0x12400d600] mb I  I16..4: 55.0% 43.1%  1.8%
# [libx264 @ 0x12400d600] mb P  I16..4: 10.0% 40.6%  0.3%  P16..4: 17.7%  2.5%  0.9%  0.0%  0.0%    skip:28.0%
# [libx264 @ 0x12400d600] mb B  I16..4:  1.9%  2.5%  0.0%  B16..8: 15.8%  1.7%  0.1%  direct:25.2%  skip:52.8%  L0:48.9% L1:49.3% BI: 1.8%
# [libx264 @ 0x12400d600] 8x8 transform intra:72.3% inter:92.6%
# [libx264 @ 0x12400d600] coded y,uvDC,uvAC intra: 13.7% 43.5% 10.1% inter: 3.6% 30.7% 0.0%
# [libx264 @ 0x12400d600] i16 v,h,dc,p: 67% 16%  2% 15%
# [libx264 @ 0x12400d600] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20%  9% 57%  2%  3%  3%  2%  2%  2%
# [libx264 @ 0x12400d600] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 19% 15%  5% 10% 10%  7%  4%  3%
# [libx264 @ 0x12400d600] i8c dc,h,v,p: 58% 19% 19%  3%
# [libx264 @ 0x12400d600] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12400d600] ref P L0: 61.0%  7.8% 22.0%  9.2%
# [libx264 @ 0x12400d600] ref B L0: 89.2%  8.3%  2.5%
# [libx264 @ 0x12400d600] ref B L1: 97.0%  3.0%
# [libx264 @ 0x12400d600] kb/s:4957.36
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/cousin/1.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     creation_time   : 2017-03-16T03:36:27.000000Z
#     encoder         : HandBrake 1.0.3 2017022500
#   Duration: 00:00:02.43, start: 0.000000, bitrate: 1580 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1608 kb/s, 29.97 fps, 29.97 tbr, 90k tbn, 180k tbc (default)
#     Metadata:
#       creation_time   : 2017-03-16T03:36:27.000000Z
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 2 kb/s (default)
#     Metadata:
#       creation_time   : 2017-03-16T03:36:27.000000Z
#       handler_name    : Stereo
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x12b014600] using SAR=1/1
# [libx264 @ 0x12b014600] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12b014600] profile High, level 4.0
# [libx264 @ 0x12b014600] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/zoomed_videos/cousin/1.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 29.97 fps, 30k tbn, 29.97 tbc (default)
#     Metadata:
#       creation_time   : 2017-03-16T03:36:27.000000Z
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 2 kb/s (default)
#     Metadata:
#       creation_time   : 2017-03-16T03:36:27.000000Z
#       handler_name    : Stereo
# frame=   71 fps= 25 q=-1.0 Lsize=     586kB time=00:00:02.38 bitrate=2009.9kbits/s speed=0.852x
# video:582kB audio:1kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.667254%
# [libx264 @ 0x12b014600] frame I:1     Avg QP:18.56  size: 42200
# [libx264 @ 0x12b014600] frame P:19    Avg QP:19.44  size: 17452
# [libx264 @ 0x12b014600] frame B:51    Avg QP:21.82  size:  4337
# [libx264 @ 0x12b014600] consecutive B-frames:  2.8%  2.8%  4.2% 90.1%
# [libx264 @ 0x12b014600] mb I  I16..4: 30.5% 64.3%  5.2%
# [libx264 @ 0x12b014600] mb P  I16..4:  7.1%  6.1%  0.1%  P16..4: 45.9%  6.1%  4.6%  0.0%  0.0%    skip:30.1%
# [libx264 @ 0x12b014600] mb B  I16..4:  0.5%  0.4%  0.0%  B16..8: 26.4%  0.6%  0.0%  direct: 3.5%  skip:68.6%  L0:42.6% L1:56.8% BI: 0.6%
# [libx264 @ 0x12b014600] 8x8 transform intra:50.8% inter:96.3%
# [libx264 @ 0x12b014600] coded y,uvDC,uvAC intra: 22.5% 52.4% 9.4% inter: 5.2% 21.8% 0.0%
# [libx264 @ 0x12b014600] i16 v,h,dc,p: 62% 18%  9% 11%
# [libx264 @ 0x12b014600] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 41% 10% 37%  2%  2%  3%  2%  3%  1%
# [libx264 @ 0x12b014600] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 47% 14% 16%  4%  5%  5%  4%  5%  2%
# [libx264 @ 0x12b014600] i8c dc,h,v,p: 55% 19% 24%  2%
# [libx264 @ 0x12b014600] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12b014600] ref P L0: 58.9%  4.0% 25.8% 11.4%
# [libx264 @ 0x12b014600] ref B L0: 82.3% 13.7%  4.0%
# [libx264 @ 0x12b014600] ref B L1: 94.8%  5.2%
# [libx264 @ 0x12b014600] kb/s:2009.09
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/cousin/0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     creation_time   : 1970-01-01T00:00:00.000000Z
#     title           : spreadthesign
#     encoder         : Lavf52.84.0
#   Duration: 00:00:03.54, start: 0.066733, bitrate: 269 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p, 320x240, 248 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 1970-01-01T00:00:00.000000Z
#       handler_name    : VideoHandler
#     Stream #0:1(und): Data: none (rtp  / 0x20707472), 14 kb/s (default)
#     Metadata:
#       creation_time   : 2011-06-05T21:33:26.000000Z
#       handler_name    : GPAC ISO Hint Handler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x12b014000] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12b014000] profile High, level 3.0
# [libx264 @ 0x12b014000] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=11 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/zoomed_videos/cousin/0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : spreadthesign
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 480x360, q=-1--1, 29.97 fps, 30k tbn, 29.97 tbc (default)
#     Metadata:
#       creation_time   : 1970-01-01T00:00:00.000000Z
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  106 fps=0.0 q=-1.0 Lsize=      76kB time=00:00:03.43 bitrate= 181.5kbits/s speed=9.17x
# video:74kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.750069%
# [libx264 @ 0x12b014000] frame I:1     Avg QP:21.07  size:  6830
# [libx264 @ 0x12b014000] frame P:34    Avg QP:20.26  size:  1531
# [libx264 @ 0x12b014000] frame B:71    Avg QP:23.08  size:   230
# [libx264 @ 0x12b014000] consecutive B-frames:  5.7% 11.3% 11.3% 71.7%
# [libx264 @ 0x12b014000] mb I  I16..4: 17.1% 73.6%  9.3%
# [libx264 @ 0x12b014000] mb P  I16..4:  1.1%  2.8%  0.2%  P16..4: 32.8%  8.1%  5.5%  0.0%  0.0%    skip:49.5%
# [libx264 @ 0x12b014000] mb B  I16..4:  0.1%  0.2%  0.0%  B16..8: 17.7%  0.7%  0.1%  direct: 0.5%  skip:80.8%  L0:38.5% L1:59.7% BI: 1.8%
# [libx264 @ 0x12b014000] 8x8 transform intra:70.6% inter:82.0%
# [libx264 @ 0x12b014000] coded y,uvDC,uvAC intra: 47.1% 52.3% 16.6% inter: 4.8% 10.8% 0.2%
# [libx264 @ 0x12b014000] i16 v,h,dc,p: 22% 38% 22% 18%
# [libx264 @ 0x12b014000] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 17% 32%  4%  5%  5%  6%  5%  5%
# [libx264 @ 0x12b014000] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 31% 16%  4%  6%  6%  4%  5%  2%
# [libx264 @ 0x12b014000] i8c dc,h,v,p: 48% 28% 20%  4%
# [libx264 @ 0x12b014000] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12b014000] ref P L0: 69.7%  8.0% 16.8%  5.4%
# [libx264 @ 0x12b014000] ref B L0: 88.1%  9.9%  2.1%
# [libx264 @ 0x12b014000] ref B L1: 96.4%  3.6%
# [libx264 @ 0x12b014000] kb/s:170.12

# %%
import os
import shutil
import subprocess

# Create the zoomed_videos folder if it doesn't already exist
if not os.path.exists(os.path.join('videos', 'zoomed_videos')):
    os.mkdir(os.path.join('videos', 'zoomed_videos'))

import os
import subprocess

# Iterate over the subdirectories in the signed_videos folder
for subdir in os.listdir(os.path.join('videos', 'signed_videos')):
    # Ignore .DS_Store files
    if subdir == '.DS_Store':
        continue
    # Create a corresponding subdirectory in the zoomed_videos folder
    if not os.path.exists(os.path.join('videos', 'zoomed_videos', subdir)):
        os.mkdir(os.path.join('videos', 'zoomed_videos', subdir))
    # Iterate over the MOV files in the current subdirectory
    for file in os.listdir(os.path.join('videos', 'signed_videos', subdir)):
        # Ignore .DS_Store files
        if file == '.DS_Store':
            continue
        if file.endswith('.mp4'):
            input_path = os.path.join('videos', 'signed_videos', subdir, file)
            output_path = os.path.join('videos', 'zoomed_videos', subdir, file)
            # Use ffmpeg to scale the video by 1.2x and then crop it back to its original size
            subprocess.run(['ffmpeg', '-i', input_path, '-vf', 'scale=1.2*iw:1.2*ih,crop=iw/1.2:ih/1.2', '-c:a', 'copy', output_path])
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/hindi/7.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2023-05-10T16:57:51.000000Z
#     com.apple.quicktime.location.accuracy.horizontal: 35.000000
#     com.apple.quicktime.location.ISO6709: +14.6595+121.0293+040.247/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone XR
#     com.apple.quicktime.software: 15.6.1
#     com.apple.quicktime.creationdate: 2023-05-11T00:39:45+0800
#     com.apple.photos.originating.signature: AU6nke/QX011N/wFNNSqsJ8AOCN4
#   Duration: 00:00:03.44, start: 0.000000, bitrate: 15338 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 175 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:57:51.000000Z
#       handler_name    : Core Media Audio
#     Stream #0:1(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080, 15076 kb/s, 29.99 fps, 29.97 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       rotate          : 90
#       creation_time   : 2023-05-10T16:57:51.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
#     Side data:
#       displaymatrix: rotation of -90.00 degrees
#     Stream #0:2(und): Data: none (mebx / 0x7862656D), 0 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:57:51.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:3(und): Data: none (mebx / 0x7862656D), 23 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:57:51.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:4(und): Data: none (mebx / 0x7862656D), 42 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:57:51.000000Z
#       handler_name    : Core Media Metadata
# Stream mapping:
#   Stream #0:1 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x12f80d200] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12f80d200] profile High, level 3.1
# [libx264 @ 0x12f80d200] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/zoomed_videos/hindi/7.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.photos.originating.signature: AU6nke/QX011N/wFNNSqsJ8AOCN4
#     com.apple.quicktime.location.accuracy.horizontal: 35.000000
#     com.apple.quicktime.location.ISO6709: +14.6595+121.0293+040.247/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone XR
#     com.apple.quicktime.software: 15.6.1
#     com.apple.quicktime.creationdate: 2023-05-11T00:39:45+0800
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720, q=-1--1, 25 fps, 12800 tbn, 25 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#       creation_time   : 2023-05-10T16:57:51.000000Z
#       handler_name    : Core Media Video
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#       displaymatrix: rotation of -0.00 degrees
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 175 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:57:51.000000Z
#       handler_name    : Core Media Audio
# frame=  103 fps= 30 q=-1.0 Lsize=     859kB time=00:00:04.00 bitrate=1759.8kbits/s speed=1.15x
# video:780kB audio:74kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.518396%
# [libx264 @ 0x12f80d200] frame I:1     Avg QP:24.18  size: 33984
# [libx264 @ 0x12f80d200] frame P:26    Avg QP:23.16  size: 14944
# [libx264 @ 0x12f80d200] frame B:76    Avg QP:24.80  size:  4946
# [libx264 @ 0x12f80d200] consecutive B-frames:  1.0%  1.9%  0.0% 97.1%
# [libx264 @ 0x12f80d200] mb I  I16..4: 21.2% 66.4% 12.4%
# [libx264 @ 0x12f80d200] mb P  I16..4:  5.6%  9.1%  0.9%  P16..4: 48.1% 11.0%  5.4%  0.0%  0.0%    skip:19.9%
# [libx264 @ 0x12f80d200] mb B  I16..4:  0.5%  0.8%  0.1%  B16..8: 42.1%  3.8%  0.4%  direct: 1.6%  skip:50.7%  L0:42.9% L1:52.8% BI: 4.3%
# [libx264 @ 0x12f80d200] 8x8 transform intra:59.7% inter:84.7%
# [libx264 @ 0x12f80d200] coded y,uvDC,uvAC intra: 41.5% 41.8% 5.0% inter: 13.3% 14.9% 0.1%
# [libx264 @ 0x12f80d200] i16 v,h,dc,p: 10% 45%  8% 36%
# [libx264 @ 0x12f80d200] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  9% 27% 30%  3%  6%  4% 10%  3%  8%
# [libx264 @ 0x12f80d200] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 38% 16%  4%  6%  5% 10%  2%  6%
# [libx264 @ 0x12f80d200] i8c dc,h,v,p: 53% 33% 10%  4%
# [libx264 @ 0x12f80d200] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12f80d200] ref P L0: 49.7% 10.9% 26.5% 12.9%
# [libx264 @ 0x12f80d200] ref B L0: 85.0% 12.0%  3.0%
# [libx264 @ 0x12f80d200] ref B L1: 94.8%  5.2%
# [libx264 @ 0x12f80d200] kb/s:1550.36
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/hindi/6.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2023-05-10T16:56:20.000000Z
#     com.apple.quicktime.location.accuracy.horizontal: 35.000000
#     com.apple.quicktime.location.ISO6709: +14.6596+121.0292+040.211/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone XR
#     com.apple.quicktime.software: 15.6.1
#     com.apple.quicktime.creationdate: 2023-05-11T00:40:29+0800
#     com.apple.photos.originating.signature: AYtudd3zfLa9+p/vE9LaiN2/RpNd
#   Duration: 00:00:02.33, start: 0.000000, bitrate: 15497 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 179 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:20.000000Z
#       handler_name    : Core Media Audio
#     Stream #0:1(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080, 15223 kb/s, 30 fps, 29.97 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       rotate          : 90
#       creation_time   : 2023-05-10T16:56:20.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
#     Side data:
#       displaymatrix: rotation of -90.00 degrees
#     Stream #0:2(und): Data: none (mebx / 0x7862656D), 0 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:20.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:3(und): Data: none (mebx / 0x7862656D), 23 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:20.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:4(und): Data: none (mebx / 0x7862656D), 42 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:20.000000Z
#       handler_name    : Core Media Metadata
# Stream mapping:
#   Stream #0:1 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x15c809e00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x15c809e00] profile High, level 3.1
# [libx264 @ 0x15c809e00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/zoomed_videos/hindi/6.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.photos.originating.signature: AYtudd3zfLa9+p/vE9LaiN2/RpNd
#     com.apple.quicktime.location.accuracy.horizontal: 35.000000
#     com.apple.quicktime.location.ISO6709: +14.6596+121.0292+040.211/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone XR
#     com.apple.quicktime.software: 15.6.1
#     com.apple.quicktime.creationdate: 2023-05-11T00:40:29+0800
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720, q=-1--1, 25 fps, 12800 tbn, 25 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#       creation_time   : 2023-05-10T16:56:20.000000Z
#       handler_name    : Core Media Video
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#       displaymatrix: rotation of -0.00 degrees
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 179 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:20.000000Z
#       handler_name    : Core Media Audio
# frame=   70 fps= 34 q=-1.0 Lsize=     513kB time=00:00:02.68 bitrate=1568.9kbits/s speed=1.32x
# video:457kB audio:52kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.679262%
# [libx264 @ 0x15c809e00] frame I:1     Avg QP:23.50  size: 24794
# [libx264 @ 0x15c809e00] frame P:18    Avg QP:23.46  size: 13304
# [libx264 @ 0x15c809e00] frame B:51    Avg QP:24.53  size:  3987
# [libx264 @ 0x15c809e00] consecutive B-frames:  2.9%  0.0%  0.0% 97.1%
# [libx264 @ 0x15c809e00] mb I  I16..4: 33.9% 58.6%  7.6%
# [libx264 @ 0x15c809e00] mb P  I16..4:  4.9%  5.8%  0.8%  P16..4: 44.8% 10.6%  5.8%  0.0%  0.0%    skip:27.3%
# [libx264 @ 0x15c809e00] mb B  I16..4:  0.7%  0.7%  0.0%  B16..8: 37.6%  3.0%  0.3%  direct: 1.2%  skip:56.3%  L0:42.4% L1:52.6% BI: 5.0%
# [libx264 @ 0x15c809e00] 8x8 transform intra:51.8% inter:85.6%
# [libx264 @ 0x15c809e00] coded y,uvDC,uvAC intra: 36.9% 40.5% 4.7% inter: 10.6% 13.4% 0.1%
# [libx264 @ 0x15c809e00] i16 v,h,dc,p: 10% 49%  7% 34%
# [libx264 @ 0x15c809e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 30% 25%  5%  5%  4%  9%  3%  9%
# [libx264 @ 0x15c809e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 39% 15%  4%  5%  3% 10%  2%  7%
# [libx264 @ 0x15c809e00] i8c dc,h,v,p: 51% 34% 11%  4%
# [libx264 @ 0x15c809e00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x15c809e00] ref P L0: 51.3% 11.1% 27.0% 10.5%
# [libx264 @ 0x15c809e00] ref B L0: 84.4% 12.3%  3.4%
# [libx264 @ 0x15c809e00] ref B L1: 94.8%  5.2%
# [libx264 @ 0x15c809e00] kb/s:1336.04
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/hindi/4.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2023-05-10T16:56:19.000000Z
#     com.apple.quicktime.location.accuracy.horizontal: 35.000000
#     com.apple.quicktime.location.ISO6709: +14.6596+121.0292+040.194/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone XR
#     com.apple.quicktime.software: 15.6.1
#     com.apple.quicktime.creationdate: 2023-05-11T00:40:24+0800
#     com.apple.photos.originating.signature: Aamc5rV2glB3mspW+hKEWYnNTnVX
#   Duration: 00:00:02.54, start: 0.000000, bitrate: 15424 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 180 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:19.000000Z
#       handler_name    : Core Media Audio
#     Stream #0:1(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080, 15150 kb/s, 29.98 fps, 29.97 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       rotate          : 90
#       creation_time   : 2023-05-10T16:56:19.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
#     Side data:
#       displaymatrix: rotation of -90.00 degrees
#     Stream #0:2(und): Data: none (mebx / 0x7862656D), 0 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:19.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:3(und): Data: none (mebx / 0x7862656D), 23 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:19.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:4(und): Data: none (mebx / 0x7862656D), 42 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:19.000000Z
#       handler_name    : Core Media Metadata
# Stream mapping:
#   Stream #0:1 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x12280d200] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12280d200] profile High, level 3.1
# [libx264 @ 0x12280d200] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/zoomed_videos/hindi/4.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.photos.originating.signature: Aamc5rV2glB3mspW+hKEWYnNTnVX
#     com.apple.quicktime.location.accuracy.horizontal: 35.000000
#     com.apple.quicktime.location.ISO6709: +14.6596+121.0292+040.194/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone XR
#     com.apple.quicktime.software: 15.6.1
#     com.apple.quicktime.creationdate: 2023-05-11T00:40:24+0800
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720, q=-1--1, 25 fps, 12800 tbn, 25 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#       creation_time   : 2023-05-10T16:56:19.000000Z
#       handler_name    : Core Media Video
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#       displaymatrix: rotation of -0.00 degrees
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 180 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:19.000000Z
#       handler_name    : Core Media Audio
# frame=   76 fps= 34 q=-1.0 Lsize=     533kB time=00:00:02.92 bitrate=1495.6kbits/s speed=1.31x
# video:472kB audio:57kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.688701%
# [libx264 @ 0x12280d200] frame I:1     Avg QP:23.14  size: 26888
# [libx264 @ 0x12280d200] frame P:19    Avg QP:23.39  size: 13055
# [libx264 @ 0x12280d200] frame B:56    Avg QP:24.34  size:  3711
# [libx264 @ 0x12280d200] consecutive B-frames:  1.3%  0.0%  3.9% 94.7%
# [libx264 @ 0x12280d200] mb I  I16..4: 35.5% 55.2%  9.3%
# [libx264 @ 0x12280d200] mb P  I16..4:  4.5%  4.6%  0.6%  P16..4: 45.3% 11.2%  5.9%  0.0%  0.0%    skip:27.9%
# [libx264 @ 0x12280d200] mb B  I16..4:  0.7%  0.6%  0.1%  B16..8: 37.0%  2.6%  0.2%  direct: 1.1%  skip:57.6%  L0:43.5% L1:52.2% BI: 4.3%
# [libx264 @ 0x12280d200] 8x8 transform intra:49.7% inter:84.7%
# [libx264 @ 0x12280d200] coded y,uvDC,uvAC intra: 35.3% 40.9% 5.2% inter: 10.2% 12.9% 0.1%
# [libx264 @ 0x12280d200] i16 v,h,dc,p:  8% 54%  5% 33%
# [libx264 @ 0x12280d200] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 28% 26%  5%  5%  4%  9%  3%  9%
# [libx264 @ 0x12280d200] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 40% 14%  4%  6%  3% 10%  2%  7%
# [libx264 @ 0x12280d200] i8c dc,h,v,p: 52% 34% 10%  4%
# [libx264 @ 0x12280d200] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12280d200] ref P L0: 51.4%  9.8% 27.3% 11.5%
# [libx264 @ 0x12280d200] ref B L0: 83.7% 12.5%  3.8%
# [libx264 @ 0x12280d200] ref B L1: 94.5%  5.5%
# [libx264 @ 0x12280d200] kb/s:1270.38
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/hindi/5.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2023-05-10T16:56:19.000000Z
#     com.apple.quicktime.location.accuracy.horizontal: 35.000000
#     com.apple.quicktime.location.ISO6709: +14.6596+121.0292+040.194/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone XR
#     com.apple.quicktime.software: 15.6.1
#     com.apple.quicktime.creationdate: 2023-05-11T00:40:24+0800
#     com.apple.photos.originating.signature: Aamc5rV2glB3mspW+hKEWYnNTnVX
#   Duration: 00:00:02.54, start: 0.000000, bitrate: 15424 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 180 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:19.000000Z
#       handler_name    : Core Media Audio
#     Stream #0:1(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080, 15150 kb/s, 29.98 fps, 29.97 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       rotate          : 90
#       creation_time   : 2023-05-10T16:56:19.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
#     Side data:
#       displaymatrix: rotation of -90.00 degrees
#     Stream #0:2(und): Data: none (mebx / 0x7862656D), 0 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:19.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:3(und): Data: none (mebx / 0x7862656D), 23 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:19.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:4(und): Data: none (mebx / 0x7862656D), 42 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:19.000000Z
#       handler_name    : Core Media Metadata
# Stream mapping:
#   Stream #0:1 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x14583ce00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x14583ce00] profile High, level 3.1
# [libx264 @ 0x14583ce00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/zoomed_videos/hindi/5.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.photos.originating.signature: Aamc5rV2glB3mspW+hKEWYnNTnVX
#     com.apple.quicktime.location.accuracy.horizontal: 35.000000
#     com.apple.quicktime.location.ISO6709: +14.6596+121.0292+040.194/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone XR
#     com.apple.quicktime.software: 15.6.1
#     com.apple.quicktime.creationdate: 2023-05-11T00:40:24+0800
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720, q=-1--1, 25 fps, 12800 tbn, 25 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#       creation_time   : 2023-05-10T16:56:19.000000Z
#       handler_name    : Core Media Video
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#       displaymatrix: rotation of -0.00 degrees
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 180 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:19.000000Z
#       handler_name    : Core Media Audio
# frame=   76 fps= 32 q=-1.0 Lsize=     533kB time=00:00:02.92 bitrate=1495.6kbits/s speed=1.25x
# video:472kB audio:57kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.688701%
# [libx264 @ 0x14583ce00] frame I:1     Avg QP:23.14  size: 26888
# [libx264 @ 0x14583ce00] frame P:19    Avg QP:23.39  size: 13055
# [libx264 @ 0x14583ce00] frame B:56    Avg QP:24.34  size:  3711
# [libx264 @ 0x14583ce00] consecutive B-frames:  1.3%  0.0%  3.9% 94.7%
# [libx264 @ 0x14583ce00] mb I  I16..4: 35.5% 55.2%  9.3%
# [libx264 @ 0x14583ce00] mb P  I16..4:  4.5%  4.6%  0.6%  P16..4: 45.3% 11.2%  5.9%  0.0%  0.0%    skip:27.9%
# [libx264 @ 0x14583ce00] mb B  I16..4:  0.7%  0.6%  0.1%  B16..8: 37.0%  2.6%  0.2%  direct: 1.1%  skip:57.6%  L0:43.5% L1:52.2% BI: 4.3%
# [libx264 @ 0x14583ce00] 8x8 transform intra:49.7% inter:84.7%
# [libx264 @ 0x14583ce00] coded y,uvDC,uvAC intra: 35.3% 40.9% 5.2% inter: 10.2% 12.9% 0.1%
# [libx264 @ 0x14583ce00] i16 v,h,dc,p:  8% 54%  5% 33%
# [libx264 @ 0x14583ce00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 28% 26%  5%  5%  4%  9%  3%  9%
# [libx264 @ 0x14583ce00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 40% 14%  4%  6%  3% 10%  2%  7%
# [libx264 @ 0x14583ce00] i8c dc,h,v,p: 52% 34% 10%  4%
# [libx264 @ 0x14583ce00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x14583ce00] ref P L0: 51.4%  9.8% 27.3% 11.5%
# [libx264 @ 0x14583ce00] ref B L0: 83.7% 12.5%  3.8%
# [libx264 @ 0x14583ce00] ref B L1: 94.5%  5.5%
# [libx264 @ 0x14583ce00] kb/s:1270.38
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/hindi/1.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2023-05-10T16:57:50.000000Z
#     com.apple.quicktime.location.accuracy.horizontal: 35.000000
#     com.apple.quicktime.location.ISO6709: +14.6596+121.0292+040.221/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone XR
#     com.apple.quicktime.software: 15.6.1
#     com.apple.quicktime.creationdate: 2023-05-11T00:39:39+0800
#     com.apple.photos.originating.signature: AfeC+EZfSLb+eR6EhdB1n3RcbMvF
#   Duration: 00:00:03.37, start: 0.000000, bitrate: 15382 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 171 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:57:50.000000Z
#       handler_name    : Core Media Audio
#     Stream #0:1(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080, 15123 kb/s, 29.99 fps, 29.97 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       rotate          : 90
#       creation_time   : 2023-05-10T16:57:50.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
#     Side data:
#       displaymatrix: rotation of -90.00 degrees
#     Stream #0:2(und): Data: none (mebx / 0x7862656D), 0 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:57:50.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:3(und): Data: none (mebx / 0x7862656D), 23 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:57:50.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:4(und): Data: none (mebx / 0x7862656D), 42 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:57:50.000000Z
#       handler_name    : Core Media Metadata
# Stream mapping:
#   Stream #0:1 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x105026a00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x105026a00] profile High, level 3.1
# [libx264 @ 0x105026a00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/zoomed_videos/hindi/1.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.photos.originating.signature: AfeC+EZfSLb+eR6EhdB1n3RcbMvF
#     com.apple.quicktime.location.accuracy.horizontal: 35.000000
#     com.apple.quicktime.location.ISO6709: +14.6596+121.0292+040.221/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone XR
#     com.apple.quicktime.software: 15.6.1
#     com.apple.quicktime.creationdate: 2023-05-11T00:39:39+0800
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720, q=-1--1, 25 fps, 12800 tbn, 25 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#       creation_time   : 2023-05-10T16:57:50.000000Z
#       handler_name    : Core Media Video
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#       displaymatrix: rotation of -0.00 degrees
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 171 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:57:50.000000Z
#       handler_name    : Core Media Audio
# frame=  101 fps= 29 q=-1.0 Lsize=     837kB time=00:00:03.92 bitrate=1748.8kbits/s speed=1.14x
# video:760kB audio:72kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.524827%
# [libx264 @ 0x105026a00] frame I:1     Avg QP:24.29  size: 38771
# [libx264 @ 0x105026a00] frame P:25    Avg QP:23.16  size: 15065
# [libx264 @ 0x105026a00] frame B:75    Avg QP:24.70  size:  4834
# [libx264 @ 0x105026a00] consecutive B-frames:  1.0%  0.0%  0.0% 99.0%
# [libx264 @ 0x105026a00] mb I  I16..4: 18.8% 69.0% 12.2%
# [libx264 @ 0x105026a00] mb P  I16..4:  5.5%  9.0%  0.7%  P16..4: 49.1% 11.0%  5.7%  0.0%  0.0%    skip:18.9%
# [libx264 @ 0x105026a00] mb B  I16..4:  0.5%  0.9%  0.1%  B16..8: 42.7%  3.3%  0.3%  direct: 1.6%  skip:50.6%  L0:43.2% L1:53.1% BI: 3.6%
# [libx264 @ 0x105026a00] 8x8 transform intra:61.1% inter:85.6%
# [libx264 @ 0x105026a00] coded y,uvDC,uvAC intra: 41.0% 42.2% 5.4% inter: 13.5% 15.6% 0.1%
# [libx264 @ 0x105026a00] i16 v,h,dc,p: 13% 42%  9% 37%
# [libx264 @ 0x105026a00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10% 24% 32%  3%  6%  5%  9%  3%  7%
# [libx264 @ 0x105026a00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 35% 17%  4%  6%  5%  8%  2%  6%
# [libx264 @ 0x105026a00] i8c dc,h,v,p: 54% 30% 11%  4%
# [libx264 @ 0x105026a00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x105026a00] ref P L0: 52.7% 10.3% 26.2% 10.9%
# [libx264 @ 0x105026a00] ref B L0: 85.9% 11.1%  2.9%
# [libx264 @ 0x105026a00] ref B L1: 94.0%  6.0%
# [libx264 @ 0x105026a00] kb/s:1540.51
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/hindi/0.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2023-05-14T07:08:12.000000Z
#     com.apple.quicktime.location.accuracy.horizontal: 40.000000
#     com.apple.quicktime.location.ISO6709: +14.6199+121.0611+045.337/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone 12
#     com.apple.quicktime.software: 16.4.1
#     com.apple.quicktime.creationdate: 2023-05-14T14:50:24+0800
#     com.apple.photos.originating.signature: AZibIB8b9n/buT7+s1HpDx/DeKT+
#   Duration: 00:00:03.35, start: 0.000000, bitrate: 15301 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 160 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-14T07:08:12.000000Z
#       handler_name    : Core Media Audio
#     Stream #0:1(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080, 15100 kb/s, 30.16 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       rotate          : 270
#       creation_time   : 2023-05-14T07:08:12.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
#     Side data:
#       displaymatrix: rotation of 90.00 degrees
#     Stream #0:2(und): Data: none (mebx / 0x7862656D), 0 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-14T07:08:12.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:3(und): Data: none (mebx / 0x7862656D), 24 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-14T07:08:12.000000Z
#       handler_name    : Core Media Metadata
# Stream mapping:
#   Stream #0:1 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x13d809400] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13d809400] profile High, level 3.1
# [libx264 @ 0x13d809400] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/zoomed_videos/hindi/0.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.photos.originating.signature: AZibIB8b9n/buT7+s1HpDx/DeKT+
#     com.apple.quicktime.location.accuracy.horizontal: 40.000000
#     com.apple.quicktime.location.ISO6709: +14.6199+121.0611+045.337/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone 12
#     com.apple.quicktime.software: 16.4.1
#     com.apple.quicktime.creationdate: 2023-05-14T14:50:24+0800
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720, q=-1--1, 25 fps, 12800 tbn, 25 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#       creation_time   : 2023-05-14T07:08:12.000000Z
#       handler_name    : Core Media Video
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#       displaymatrix: rotation of -0.00 degrees
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 160 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-14T07:08:12.000000Z
#       handler_name    : Core Media Audio
# frame=  101 fps= 24 q=-1.0 Lsize=     813kB time=00:00:03.92 bitrate=1699.5kbits/s speed=0.916x
# video:743kB audio:66kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.537221%
# [libx264 @ 0x13d809400] frame I:1     Avg QP:22.52  size: 44414
# [libx264 @ 0x13d809400] frame P:25    Avg QP:22.87  size: 15501
# [libx264 @ 0x13d809400] frame B:75    Avg QP:25.47  size:  4370
# [libx264 @ 0x13d809400] consecutive B-frames:  1.0%  0.0%  0.0% 99.0%
# [libx264 @ 0x13d809400] mb I  I16..4:  8.9% 74.7% 16.4%
# [libx264 @ 0x13d809400] mb P  I16..4:  1.9%  5.7%  0.6%  P16..4: 50.5% 14.8%  7.6%  0.0%  0.0%    skip:18.9%
# [libx264 @ 0x13d809400] mb B  I16..4:  0.2%  0.7%  0.1%  B16..8: 36.4%  3.0%  0.3%  direct: 1.9%  skip:57.4%  L0:40.4% L1:56.3% BI: 3.3%
# [libx264 @ 0x13d809400] 8x8 transform intra:72.3% inter:82.0%
# [libx264 @ 0x13d809400] coded y,uvDC,uvAC intra: 61.1% 56.6% 10.2% inter: 15.5% 21.2% 0.3%
# [libx264 @ 0x13d809400] i16 v,h,dc,p:  4% 53%  4% 38%
# [libx264 @ 0x13d809400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  5% 38% 16%  4%  6%  3% 16%  3% 10%
# [libx264 @ 0x13d809400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  5% 52% 11%  2%  5%  2% 16%  1%  5%
# [libx264 @ 0x13d809400] i8c dc,h,v,p: 46% 41%  7%  6%
# [libx264 @ 0x13d809400] Weighted P-Frames: Y:4.0% UV:0.0%
# [libx264 @ 0x13d809400] ref P L0: 54.2% 12.2% 23.8%  9.4%  0.3%
# [libx264 @ 0x13d809400] ref B L0: 85.9% 11.1%  3.0%
# [libx264 @ 0x13d809400] ref B L1: 94.4%  5.6%
# [libx264 @ 0x13d809400] kb/s:1504.35
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/hindi/2.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2023-05-10T16:56:17.000000Z
#     com.apple.quicktime.location.accuracy.horizontal: 35.000000
#     com.apple.quicktime.location.ISO6709: +14.6596+121.0292+040.168/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone XR
#     com.apple.quicktime.software: 15.6.1
#     com.apple.quicktime.creationdate: 2023-05-11T00:38:35+0800
#     com.apple.photos.originating.signature: AWgBS0mt2mLNn9lPzmGMAt9Ik2l7
#   Duration: 00:00:03.14, start: 0.000000, bitrate: 15493 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 178 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:17.000000Z
#       handler_name    : Core Media Audio
#     Stream #0:1(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080, 15225 kb/s, 29.97 fps, 29.97 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       rotate          : 90
#       creation_time   : 2023-05-10T16:56:17.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
#     Side data:
#       displaymatrix: rotation of -90.00 degrees
#     Stream #0:2(und): Data: none (mebx / 0x7862656D), 0 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:17.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:3(und): Data: none (mebx / 0x7862656D), 23 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:17.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:4(und): Data: none (mebx / 0x7862656D), 42 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:17.000000Z
#       handler_name    : Core Media Metadata
# Stream mapping:
#   Stream #0:1 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x148833800] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x148833800] profile High, level 3.1
# [libx264 @ 0x148833800] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/zoomed_videos/hindi/2.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.photos.originating.signature: AWgBS0mt2mLNn9lPzmGMAt9Ik2l7
#     com.apple.quicktime.location.accuracy.horizontal: 35.000000
#     com.apple.quicktime.location.ISO6709: +14.6596+121.0292+040.168/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone XR
#     com.apple.quicktime.software: 15.6.1
#     com.apple.quicktime.creationdate: 2023-05-11T00:38:35+0800
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720, q=-1--1, 25 fps, 12800 tbn, 25 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#       creation_time   : 2023-05-10T16:56:17.000000Z
#       handler_name    : Core Media Video
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#       displaymatrix: rotation of -0.00 degrees
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 178 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:17.000000Z
#       handler_name    : Core Media Audio
# frame=   94 fps= 27 q=-1.0 Lsize=     715kB time=00:00:03.64 bitrate=1608.4kbits/s speed=1.03x
# video:641kB audio:70kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.588003%
# [libx264 @ 0x148833800] frame I:1     Avg QP:23.26  size: 26056
# [libx264 @ 0x148833800] frame P:24    Avg QP:23.15  size: 14190
# [libx264 @ 0x148833800] frame B:69    Avg QP:24.75  size:  4186
# [libx264 @ 0x148833800] consecutive B-frames:  2.1%  0.0%  0.0% 97.9%
# [libx264 @ 0x148833800] mb I  I16..4: 31.1% 59.6%  9.4%
# [libx264 @ 0x148833800] mb P  I16..4:  5.2%  7.1%  0.8%  P16..4: 45.7% 12.1%  5.6%  0.0%  0.0%    skip:23.5%
# [libx264 @ 0x148833800] mb B  I16..4:  0.7%  0.8%  0.1%  B16..8: 40.5%  3.3%  0.3%  direct: 1.2%  skip:53.1%  L0:41.4% L1:53.4% BI: 5.1%
# [libx264 @ 0x148833800] 8x8 transform intra:54.8% inter:85.9%
# [libx264 @ 0x148833800] coded y,uvDC,uvAC intra: 37.2% 40.8% 5.6% inter: 10.9% 12.4% 0.1%
# [libx264 @ 0x148833800] i16 v,h,dc,p:  7% 55%  6% 32%
# [libx264 @ 0x148833800] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 29% 24%  4%  6%  4%  9%  3%  8%
# [libx264 @ 0x148833800] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 42% 14%  3%  5%  4%  9%  2%  6%
# [libx264 @ 0x148833800] i8c dc,h,v,p: 53% 33% 10%  4%
# [libx264 @ 0x148833800] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x148833800] ref P L0: 53.4% 11.8% 24.6% 10.2%
# [libx264 @ 0x148833800] ref B L0: 86.3% 10.8%  2.9%
# [libx264 @ 0x148833800] ref B L1: 94.7%  5.3%
# [libx264 @ 0x148833800] kb/s:1394.50
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/hindi/3.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2023-05-10T16:56:18.000000Z
#     com.apple.quicktime.location.accuracy.horizontal: 35.000000
#     com.apple.quicktime.location.ISO6709: +14.6596+121.0292+040.179/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone XR
#     com.apple.quicktime.software: 15.6.1
#     com.apple.quicktime.creationdate: 2023-05-11T00:38:41+0800
#     com.apple.photos.originating.signature: AWUY3S5tBNWl0Pfnr8qPds+najDM
#   Duration: 00:00:02.97, start: 0.000000, bitrate: 15179 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 184 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T16:56:18.000000Z
#       handler_name    : Core Media Audio
#     Stream #0:1(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080, 14906 kb/s, 29.97 fps, 29.97 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       rotate          : 90
#       creation_time   : 2023-05-10T16:56:18.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
#     Side data:
#       displaymatrix: rotation of -90.00 degrees
# ...
#       encoder         : Lavc58.54.100 libx264
#       creation_time   : 2023-05-10T17:07:15.000000Z
#       handler_name    : Core Media Video
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#       displaymatrix: rotation of -0.00 degrees
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 167 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T17:07:15.000000Z
#       handler_name    : Core Media Audio
# frame=  290 fps= 37 q=-1.0 Lsize=    2479kB time=00:00:11.48 bitrate=1769.1kbits/s speed=1.48x
# video:2372kB audio:100kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.297809%
# [libx264 @ 0x12700d200] frame I:2     Avg QP:22.96  size: 48914
# [libx264 @ 0x12700d200] frame P:73    Avg QP:23.86  size: 18884
# [libx264 @ 0x12700d200] frame B:215   Avg QP:25.83  size:  4427
# [libx264 @ 0x12700d200] consecutive B-frames:  1.0%  0.0%  1.0% 97.9%
# [libx264 @ 0x12700d200] mb I  I16..4: 10.2% 73.4% 16.5%
# [libx264 @ 0x12700d200] mb P  I16..4:  1.9%  5.0%  0.4%  P16..4: 49.3% 18.0%  8.4%  0.0%  0.0%    skip:17.0%
# [libx264 @ 0x12700d200] mb B  I16..4:  0.3%  0.6%  0.0%  B16..8: 38.7%  3.4%  0.4%  direct: 1.9%  skip:54.7%  L0:43.4% L1:52.2% BI: 4.4%
# [libx264 @ 0x12700d200] 8x8 transform intra:68.4% inter:81.7%
# [libx264 @ 0x12700d200] coded y,uvDC,uvAC intra: 55.9% 50.5% 7.5% inter: 16.8% 15.8% 0.1%
# [libx264 @ 0x12700d200] i16 v,h,dc,p: 12% 41%  8% 39%
# [libx264 @ 0x12700d200] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 30% 20%  4%  6%  4% 10%  4% 10%
# [libx264 @ 0x12700d200] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10% 46% 11%  4%  6%  3% 10%  3%  7%
# [libx264 @ 0x12700d200] i8c dc,h,v,p: 51% 35% 10%  4%
# [libx264 @ 0x12700d200] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x12700d200] ref P L0: 47.4% 12.8% 29.6% 10.2%
# [libx264 @ 0x12700d200] ref B L0: 85.2% 12.0%  2.8%
# [libx264 @ 0x12700d200] ref B L1: 95.0%  5.0%
# [libx264 @ 0x12700d200] kb/s:1674.61
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/oo/1.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2023-05-14T07:09:30.000000Z
#     com.apple.quicktime.location.accuracy.horizontal: 40.000000
#     com.apple.quicktime.location.ISO6709: +14.6199+121.0611+045.337/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone 12
#     com.apple.quicktime.software: 16.4.1
#     com.apple.quicktime.creationdate: 2023-05-14T14:50:24+0800
#     com.apple.photos.originating.signature: AXdBHbEubrJep3gQa1BmTgJYZX0j
#   Duration: 00:00:01.79, start: 0.000000, bitrate: 15032 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 160 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-14T07:09:30.000000Z
#       handler_name    : Core Media Audio
#     Stream #0:1(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080, 14821 kb/s, 30.73 fps, 30 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       rotate          : 270
#       creation_time   : 2023-05-14T07:09:30.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
#     Side data:
#       displaymatrix: rotation of 90.00 degrees
#     Stream #0:2(und): Data: none (mebx / 0x7862656D), 0 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-14T07:09:30.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:3(und): Data: none (mebx / 0x7862656D), 24 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-14T07:09:30.000000Z
#       handler_name    : Core Media Metadata
# Stream mapping:
#   Stream #0:1 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x129009e00] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x129009e00] profile High, level 3.1
# [libx264 @ 0x129009e00] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/zoomed_videos/oo/1.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.photos.originating.signature: AXdBHbEubrJep3gQa1BmTgJYZX0j
#     com.apple.quicktime.location.accuracy.horizontal: 40.000000
#     com.apple.quicktime.location.ISO6709: +14.6199+121.0611+045.337/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone 12
#     com.apple.quicktime.software: 16.4.1
#     com.apple.quicktime.creationdate: 2023-05-14T14:50:24+0800
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720, q=-1--1, 25 fps, 12800 tbn, 25 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#       creation_time   : 2023-05-14T07:09:30.000000Z
#       handler_name    : Core Media Video
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#       displaymatrix: rotation of -0.00 degrees
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 160 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-14T07:09:30.000000Z
#       handler_name    : Core Media Audio
# frame=   55 fps= 19 q=-1.0 Lsize=     446kB time=00:00:02.08 bitrate=1757.7kbits/s speed=0.714x
# video:407kB audio:36kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.672742%
# [libx264 @ 0x129009e00] frame I:1     Avg QP:22.74  size: 45621
# [libx264 @ 0x129009e00] frame P:14    Avg QP:23.14  size: 14870
# [libx264 @ 0x129009e00] frame B:40    Avg QP:25.61  size:  4070
# [libx264 @ 0x129009e00] consecutive B-frames:  1.8%  3.6%  0.0% 94.5%
# [libx264 @ 0x129009e00] mb I  I16..4:  9.2% 73.6% 17.2%
# [libx264 @ 0x129009e00] mb P  I16..4:  1.2%  3.9%  0.4%  P16..4: 48.6% 15.1%  7.7%  0.0%  0.0%    skip:23.1%
# [libx264 @ 0x129009e00] mb B  I16..4:  0.1%  0.2%  0.0%  B16..8: 36.0%  3.0%  0.3%  direct: 1.7%  skip:58.8%  L0:37.5% L1:58.5% BI: 4.0%
# [libx264 @ 0x129009e00] 8x8 transform intra:72.0% inter:81.8%
# [libx264 @ 0x129009e00] coded y,uvDC,uvAC intra: 68.1% 56.8% 12.1% inter: 14.9% 19.6% 0.3%
# [libx264 @ 0x129009e00] i16 v,h,dc,p:  4% 54%  4% 38%
# [libx264 @ 0x129009e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  5% 37% 17%  4%  5%  3% 16%  3% 10%
# [libx264 @ 0x129009e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  5% 54% 10%  2%  4%  2% 15%  1%  6%
# [libx264 @ 0x129009e00] i8c dc,h,v,p: 46% 42%  7%  6%
# [libx264 @ 0x129009e00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x129009e00] ref P L0: 54.5% 13.9% 23.0%  8.6%
# [libx264 @ 0x129009e00] ref B L0: 86.2% 11.1%  2.7%
# [libx264 @ 0x129009e00] ref B L1: 94.5%  5.5%
# [libx264 @ 0x129009e00] kb/s:1514.86
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 12.0.0
#   configuration: --prefix=/Users/ktietz/demo/mc3/conda-bld/ffmpeg_1628925491858/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=arm64-apple-darwin20.0.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'videos/signed_videos/oo/0.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2023-05-10T17:09:30.000000Z
#     com.apple.quicktime.location.accuracy.horizontal: 35.000000
#     com.apple.quicktime.location.ISO6709: +14.6596+121.0292+040.080/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone XR
#     com.apple.quicktime.software: 15.6.1
#     com.apple.quicktime.creationdate: 2023-05-10T21:13:17+0800
#     com.apple.photos.originating.signature: AT5ot5iTgIRNvEUm0LEbWh+RSEuz
#   Duration: 00:00:04.42, start: 0.000000, bitrate: 22567 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 173 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T17:09:30.000000Z
#       handler_name    : Core Media Audio
#     Stream #0:1(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080, 22269 kb/s, 60.02 fps, 60 tbr, 600 tbn, 1200 tbc (default)
#     Metadata:
#       rotate          : 90
#       creation_time   : 2023-05-10T17:09:30.000000Z
#       handler_name    : Core Media Video
#       encoder         : H.264
#     Side data:
#       displaymatrix: rotation of -90.00 degrees
#     Stream #0:2(und): Data: none (mebx / 0x7862656D), 0 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T17:09:30.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:3(und): Data: none (mebx / 0x7862656D), 23 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T17:09:30.000000Z
#       handler_name    : Core Media Metadata
#     Stream #0:4(und): Data: none (mebx / 0x7862656D), 76 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T17:09:30.000000Z
#       handler_name    : Core Media Metadata
# Stream mapping:
#   Stream #0:1 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [libx264 @ 0x123008800] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x123008800] profile High, level 3.1
# [libx264 @ 0x123008800] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/zoomed_videos/oo/0.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     com.apple.photos.originating.signature: AT5ot5iTgIRNvEUm0LEbWh+RSEuz
#     com.apple.quicktime.location.accuracy.horizontal: 35.000000
#     com.apple.quicktime.location.ISO6709: +14.6596+121.0292+040.080/
#     com.apple.quicktime.make: Apple
#     com.apple.quicktime.model: iPhone XR
#     com.apple.quicktime.software: 15.6.1
#     com.apple.quicktime.creationdate: 2023-05-10T21:13:17+0800
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720, q=-1--1, 25 fps, 12800 tbn, 25 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#       creation_time   : 2023-05-10T17:09:30.000000Z
#       handler_name    : Core Media Video
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#       displaymatrix: rotation of -0.00 degrees
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 173 kb/s (default)
#     Metadata:
#       creation_time   : 2023-05-10T17:09:30.000000Z
#       handler_name    : Core Media Audio
# frame=  206 fps= 32 q=28.0 size=    1024kB time=00:00:05.88 bitrate=1426.7kbits/s speed=0.911x
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 26
#      24 output_path = os.path.join('videos', 'zoomed_videos', subdir, file)
#      25 # Use ffmpeg to zoom in the video by 1.2x and save it to the output path
# ---> 26 subprocess.run(['ffmpeg', '-i', input_path, '-vf', 'zoompan=z=\'1.5\':d=1', '-c:a', 'copy', output_path])
#
# File ~/miniconda3/envs/fsltranslator/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File ~/miniconda3/envs/fsltranslator/lib/python3.10/subprocess.py:1146, in Popen.communicate(self, input, timeout)
#    1144         stderr = self.stderr.read()
#    1145         self.stderr.close()
# -> 1146     self.wait()
#    1147 else:
#    1148     if timeout is not None:
#
# File ~/miniconda3/envs/fsltranslator/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File ~/miniconda3/envs/fsltranslator/lib/python3.10/subprocess.py:1943, in Popen._wait(self, timeout)
#    1941 if self.returncode is not None:
#    1942     break  # Another thread waited.
# -> 1943 (pid, sts) = self._try_wait(0)
#    1944 # Check the pid and loop as waitpid has been known to
#    1945 # return 0 even without WNOHANG in odd situations.
#    1946 # http://bugs.python.org/issue14396.
#    1947 if pid == self.pid:
#
# File ~/miniconda3/envs/fsltranslator/lib/python3.10/subprocess.py:1901, in Popen._try_wait(self, wait_flags)
#    1899 """All callers to this function MUST hold self._waitpid_lock."""
#    1900 try:
# -> 1901     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1902 except ChildProcessError:
#    1903     # This happens if SIGCLD is set to be ignored or waiting
#    1904     # for child processes has otherwise been disabled for our
#    1905     # process.  This child is dead, we can't get the status.
#    1906     pid = self.pid
#
# KeyboardInterrupt:

# %%
import os
import shutil

# Specify the directory path
directory = 'videos/signed_videos'

# Iterate over the subdirectories in the directory
for root, dirs, files in os.walk(directory):
    for subdir in dirs:
        subdir_path = os.path.join(root, subdir)

        # Iterate over the files in the subdirectory
        for file_name in os.listdir(subdir_path):
            # Ignore non-.MOV files
            if not os.path.isfile(os.path.join(subdir_path, file_name)) or not file_name.endswith('.MOV'):
                continue

            # Construct the input and output file paths
            input_path = os.path.join(subdir_path, file_name)
            output_path = os.path.join(subdir_path, os.path.splitext(file_name)[0] + '.mp4')

            # Rename the file extension from .MOV to .mp4
            shutil.move(input_path, output_path)
